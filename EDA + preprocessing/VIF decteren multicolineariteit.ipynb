# %%
# https://www.datacamp.com/tutorial/variance-inflation-factor
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.tools.tools import add_constant

# %%
train = pd.read_csv(r"C:\Users\basde\Downloads\playground-series-s3e24\train.csv")

# %%
train[['LDL','Cholesterol']].describe()
# Out:
#                  LDL    Cholesterol
# count  159256.000000  159256.000000
# mean      114.607682     195.796165
# std        28.158931      28.396959
# min         1.000000      77.000000
# 25%        95.000000     175.000000
# 50%       114.000000     196.000000
# 75%       133.000000     217.000000
# max      1860.000000     393.000000

# %%
plt.figure(figsize=(15, 9))
sns.heatmap(train.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
X = train.drop(columns=['smoking'])

# Add a constant to the model (intercept)
X = add_constant(X)

# Calculate VIF for each feature
datacamp_vif_data = pd.DataFrame()
datacamp_vif_data['Feature'] = X.columns
datacamp_vif_data['VIF'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
print(datacamp_vif_data)
# Out:
#                 Feature           VIF
# 0                 const  19126.342418
# 1                    id      1.000137
# 2                   age      1.820463
# 3            height(cm)     54.895834
# 4            weight(kg)    162.330831
# 5             waist(cm)      4.680401
# 6        eyesight(left)      1.295670
# 7       eyesight(right)      1.303542
# 8         hearing(left)      1.464450
# 9        hearing(right)      1.466018
# 10             systolic      2.458377
# 11           relaxation      2.409603
# 12  fasting blood sugar      1.128128
# 13          Cholesterol      7.336202
# 14         triglyceride      3.001280
# 15                  HDL      3.226041
# 16                  LDL      6.107194
# 17           hemoglobin      1.859488
# 18        Urine protein      1.005058
# 19     serum creatinine      1.409416
# 20                  AST      1.742173
# 21                  ALT      1.993226
# 22                  Gtp      1.335119
# 23        dental caries      1.021645
# 24                  BMI     90.660182

# %%
test = X = train.drop(columns=['smoking','weight(kg)'])

# Add a constant to the model (intercept)
X = add_constant(X)

# Calculate VIF for each feature
datacamp_vif_data = pd.DataFrame()
datacamp_vif_data['Feature'] = X.columns
datacamp_vif_data['VIF'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
print(datacamp_vif_data)
# Out:
#                 Feature         VIF
# 0                 const  941.626726
# 1                    id    1.000136
# 2                   age    1.683934
# 3            height(cm)    2.184537
# 4             waist(cm)    1.756359
# 5        eyesight(left)    1.295118
# 6       eyesight(right)    1.303064
# 7         hearing(left)    1.464187
# 8        hearing(right)    1.465391
# 9              systolic    2.453425
# 10           relaxation    2.406050
# 11  fasting blood sugar    1.126399
# 12          Cholesterol    7.330023
# 13         triglyceride    3.001086
# 14                  HDL    3.216123
# 15                  LDL    6.107157
# 16           hemoglobin    1.847988
# 17        Urine protein    1.005023
# 18     serum creatinine    1.403443
# 19                  AST    1.741857
# 20                  ALT    1.972876
# 21                  Gtp    1.334602
# 22        dental caries    1.021436

# %%
test = X = train.drop(columns=['smoking','weight(kg)','LDL'])

# Add a constant to the model (intercept)
X = add_constant(X)

# Calculate VIF for each feature
datacamp_vif_data = pd.DataFrame()
datacamp_vif_data['Feature'] = X.columns
datacamp_vif_data['VIF'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
print(datacamp_vif_data)
# Out:
#                 Feature         VIF
# 0                 const  941.614205
# 1                    id    1.000131
# 2                   age    1.683933
# 3            height(cm)    2.184482
# 4             waist(cm)    1.756357
# 5        eyesight(left)    1.295111
# 6       eyesight(right)    1.303063
# 7         hearing(left)    1.464186
# 8        hearing(right)    1.465388
# 9              systolic    2.453394
# 10           relaxation    2.406020
# 11  fasting blood sugar    1.126396
# 12          Cholesterol    1.268006
# 13         triglyceride    1.743937
# 14                  HDL    1.777271
# 15           hemoglobin    1.847961
# 16        Urine protein    1.005022
# 17     serum creatinine    1.403363
# 18                  AST    1.741844
# 19                  ALT    1.972840
# 20                  Gtp    1.334599
# 21        dental caries    1.021435

# %%
test = X = train.drop(columns=['smoking','LDL', 'height(cm)'])

# Add a constant to the model (intercept)
X = add_constant(X)

# Calculate VIF for each feature
datacamp_vif_data = pd.DataFrame()
datacamp_vif_data['Feature'] = X.columns
datacamp_vif_data['VIF'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
print(datacamp_vif_data)
# Out:
#                 Feature         VIF
# 0                 const  466.277079
# 1                    id    1.000131
# 2                   age    1.757598
# 3            weight(kg)    5.098465
# 4             waist(cm)    4.255027
# 5        eyesight(left)    1.294337
# 6       eyesight(right)    1.302192
# 7         hearing(left)    1.464324
# 8        hearing(right)    1.465897
# 9              systolic    2.455276
# 10           relaxation    2.408531
# 11  fasting blood sugar    1.126510
# 12          Cholesterol    1.244899
# 13         triglyceride    1.742549
# 14                  HDL    1.782560
# 15           hemoglobin    1.721968
# 16        Urine protein    1.005042
# 17     serum creatinine    1.345581
# 18                  AST    1.740911
# 19                  ALT    1.980767
# 20                  Gtp    1.332195
# 21        dental caries    1.021358

# %%
test = X = train.drop(columns=['smoking','waist(cm)','LDL'])

# Add a constant to the model (intercept)
X = add_constant(X)

# Calculate VIF for each feature
datacamp_vif_data = pd.DataFrame()
datacamp_vif_data['Feature'] = X.columns
datacamp_vif_data['VIF'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
print(datacamp_vif_data)
# Out:
#                 Feature          VIF
# 0                 const  1035.226619
# 1                    id     1.000127
# 2                   age     1.691357
# 3            height(cm)     2.702677
# 4            weight(kg)     2.603727
# 5        eyesight(left)     1.294925
# 6       eyesight(right)     1.303016
# 7         hearing(left)     1.464060
# 8        hearing(right)     1.465080
# 9              systolic     2.449036
# 10           relaxation     2.408762
# 11  fasting blood sugar     1.123454
# 12          Cholesterol     1.270544
# 13         triglyceride     1.742836
# 14                  HDL     1.760492
# 15           hemoglobin     1.842390
# 16        Urine protein     1.005057
# 17     serum creatinine     1.405213
# 18                  AST     1.742099
# 19                  ALT     1.983039
# 20                  Gtp     1.331283
# 21        dental caries     1.021529

# %%
test = X = train.drop(columns=['smoking','waist(cm)','height(cm)','weight(kg)'])

# Add a constant to the model (intercept)
X = add_constant(X)

# Calculate VIF for each feature
datacamp_vif_data = pd.DataFrame()
datacamp_vif_data['Feature'] = X.columns
datacamp_vif_data['VIF'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
print(datacamp_vif_data)
# Out:
#                 Feature         VIF
# 0                 const  436.013022
# 1                    id    1.000130
# 2                   age    1.441514
# 3        eyesight(left)    1.292700
# 4       eyesight(right)    1.300367
# 5         hearing(left)    1.464026
# 6        hearing(right)    1.465083
# 7              systolic    2.447769
# 8            relaxation    2.408514
# 9   fasting blood sugar    1.123427
# 10          Cholesterol    7.319355
# 11         triglyceride    2.995149
# 12                  HDL    3.185765
# 13                  LDL    6.106975
# 14           hemoglobin    1.657662
# 15        Urine protein    1.004942
# 16     serum creatinine    1.297473
# 17                  AST    1.738282
# 18                  ALT    1.973803
# 19                  Gtp    1.326338
# 20        dental caries    1.020854
# 21                  BMI    1.415902

# %%
test = X = train.drop(columns=['smoking'])

# Add a constant to the model (intercept)
X = add_constant(X)

# Calculate VIF for each feature
datacamp_vif_data = pd.DataFrame()
datacamp_vif_data['Feature'] = X.columns
datacamp_vif_data['VIF'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
print(datacamp_vif_data)
# Out:
#                 Feature           VIF
# 0                 const  19126.342418
# 1                    id      1.000137
# 2                   age      1.820463
# 3            height(cm)     54.895834
# 4            weight(kg)    162.330831
# 5             waist(cm)      4.680401
# 6        eyesight(left)      1.295670
# 7       eyesight(right)      1.303542
# 8         hearing(left)      1.464450
# 9        hearing(right)      1.466018
# 10             systolic      2.458377
# 11           relaxation      2.409603
# 12  fasting blood sugar      1.128128
# 13          Cholesterol      7.336202
# 14         triglyceride      3.001280
# 15                  HDL      3.226041
# 16                  LDL      6.107194
# 17           hemoglobin      1.859488
# 18        Urine protein      1.005058
# 19     serum creatinine      1.409416
# 20                  AST      1.742173
# 21                  ALT      1.993226
# 22                  Gtp      1.335119
# 23        dental caries      1.021645
# 24                  BMI     90.660182

# %%
test = X = train.drop(columns=['smoking','LDL'])

# Add a constant to the model (intercept)
X = add_constant(X)

# Calculate VIF for each feature
datacamp_vif_data = pd.DataFrame()
datacamp_vif_data['Feature'] = X.columns
datacamp_vif_data['VIF'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
print(datacamp_vif_data)
# Out:
#                 Feature           VIF
# 0                 const  19126.148332
# 1                    id      1.000132
# 2                   age      1.820461
# 3            height(cm)     54.895205
# 4            weight(kg)    162.329896
# 5             waist(cm)      4.680400
# 6        eyesight(left)      1.295663
# 7       eyesight(right)      1.303541
# 8         hearing(left)      1.464449
# 9        hearing(right)      1.466016
# 10             systolic      2.458347
# 11           relaxation      2.409574
# 12  fasting blood sugar      1.128125
# 13          Cholesterol      1.274844
# 14         triglyceride      1.744176
# 15                  HDL      1.786795
# 16           hemoglobin      1.859458
# 17        Urine protein      1.005057
# 18     serum creatinine      1.409334
# 19                  AST      1.742159
# 20                  ALT      1.993192
# 21                  Gtp      1.335115
# 22        dental caries      1.021643
# 23                  BMI     90.659629

# %%
train['BMI'] = train['weight(kg)'] / (train['height(cm)'] / 100)**2
train['Chol_LDL'] = (train['LDL'] + train['Cholesterol']) * 2
train = train.drop(columns=['waist(cm)'])

# %%
test = X = train.drop(columns=['smoking','height(cm)','weight(kg)','LDL', 'Cholesterol'])

# Add a constant to the model (intercept)
X = add_constant(X)

# Calculate VIF for each feature
datacamp_vif_data = pd.DataFrame()
datacamp_vif_data['Feature'] = X.columns
datacamp_vif_data['VIF'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
print(datacamp_vif_data)
# Out:
#                 Feature         VIF
# 0                 const  450.290974
# 1                    id    1.000133
# 2                   age    1.450126
# 3             waist(cm)    3.756967
# 4        eyesight(left)    1.292696
# 5       eyesight(right)    1.300376
# 6         hearing(left)    1.464398
# 7        hearing(right)    1.465789
# 8              systolic    2.457023
# 9            relaxation    2.408767
# 10  fasting blood sugar    1.126725
# 11         triglyceride    1.576127
# 12                  HDL    1.596616
# 13           hemoglobin    1.718952
# 14        Urine protein    1.004963
# 15     serum creatinine    1.313009
# 16                  AST    1.739373
# 17                  ALT    1.981833
# 18                  Gtp    1.333643
# 19        dental caries    1.021010
# 20                  BMI    3.198224
# 21             Chol_LDL    1.083033
