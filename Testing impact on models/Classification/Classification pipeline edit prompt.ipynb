# %%
You MUST generate exactly two Python code cells.

Do NOT provide any text, explanations, or markdown outside of these two code cells.

Cell 1: Data Compliance Check. This cell must contain Python code to verify that the data (X) meets the requirements of the new configuration. If no specific data checks are needed, this cell should contain a Python comment stating so.

Cell 2: Updated Configuration. This is the edited version of the original configuration cell, updated to reflect the user's request below.

Original Configuration Cell:

Python

# a. Specify the feature to apply transformations on
# You can change 'Age' to any other numerical column name from your dataframe
feature_to_transform = 'Age'

# b. Define the classification models to evaluate
models = {
    "Logistic Regression": LogisticRegression(max_iter=1000, random_state=42),
    "Random Forest": RandomForestClassifier(random_state=42)
}

# c. Define the transformation pipelines to test on the specified feature
# The ColumnTransformer applies the specified pipeline to the 'feature_to_transform'
# and leaves the other features untouched (remainder='passthrough').
transformation_pipelines = {
    'Standard Scaler': ColumnTransformer(
        transformers=[
            ('scaler', Pipeline([
                ('imputer', SimpleImputer(strategy='median')),
                ('scaler', StandardScaler())
            ]), [feature_to_transform])
        ],
        remainder='passthrough'
    ),
    'MinMax Scaler': ColumnTransformer(
        transformers=[
            ('scaler', Pipeline([
                ('imputer', SimpleImputer(strategy='median')),
                ('scaler', MinMaxScaler())
            ]), [feature_to_transform])
        ],
        remainder='passthrough'
    )
}

# d. Define the classification scoring metrics
scoring_metrics = {
    'accuracy': 'accuracy',
    'f1_score': 'f1_weighted',
    'precision': 'precision_weighted',
    'recall': 'recall_weighted'
}

# d. Define the cross-validation strategy
cv_strategy = KFold(n_splits=5, shuffle=True, random_state=42)

User Request:
{Your Change Request Here}

# %%
How to Use the Prompt
Copy the entire template above and replace the {Your Change Request Here} placeholder with your specific instructions.

Example 1: Add a new model

"Add the SVC model from sklearn.svm to the models dictionary. Set probability=True and random_state=42."

Example 2: Change a scoring metric

"In the scoring_metrics dictionary, change the value for f1_score from 'f1_weighted' to 'f1_macro'."

Example 3: Use a different imputer

"In all transformation pipelines, replace the SimpleImputer with the KNNImputer from sklearn.impute. Use the default n_neighbors=5."
